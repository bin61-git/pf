# %% [markdown]
# # КУРС: Принятие решений в бизнесе

# %% [markdown]
# ## Постановка задачи и описание целей и этапов исследования.

# %% [markdown]
# **ДАНО:** Крупный интернет-магазин. Совместно с отделом маркетинга подготовлен список гипотез для увеличения выручки.
# **НАДО:** Приоритизировать гипотезы, запустить A/B-тест и проанализировать результаты.
# **Основные этапы**
# **Часть 1. Приоритизация гипотез.**
# •	Загрузка данных и получение общей информации о данных.
# •	Применить фреймворк ICE для приоритизации гипотез. Отсортировать их по убыванию приоритета.
# •	Применить фреймворк RICE для приоритизации гипотез. Отсортировать их по убыванию приоритета.
# •	Проверить - изменилась ли приоритизация гипотез при применении RICE вместо ICE. Если произощли изменения - дать пояснения.
# **Часть 2. Анализ A/B-теста**
# 1. Загрузка данных и получение общей информации о данных.
# 2. Проверка выборок на пересечение целевых групп. Фильтрация пересечений.
# 3.	Построение графика кумулятивной выручки по группам. Выводы и предположения.
# 4.	Построение графика кумулятивного среднего чека по группам. Выводы и предположения.
# 5.	Построение графика относительного изменения кумулятивного среднего чека группы B к группе A. Выводы и предположения.
# 6.	Построение графика кумулятивного среднего количества заказов на посетителя по группам. Выводы и предположения.
# 7.	Построение графика относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A. Выводы и предположения.
# 8.	Построение точечного графика количества заказов по пользователям. Выводы и предположения.
# 9.	Вычисление 95-го и 99-го перцентилей количества заказов на пользователя. Выбор границы для определения аномальных пользователей.
# 10.	Построение точечного графика стоимостей заказов. Выводы и предположения.
# 11.	Вычисление 95-го и 99-го перцентилей стоимости заказов. Выбор границы для определения аномальных заказов.
# 12.	Вычисление статистической значимости различий в среднем количестве заказов на посетителя между группами по «сырым» данным. Выводы и предположения.
# 13.	Вычисление статистической значимости различий в среднем чеке заказа между группами по «сырым» данным. Выводы и предположения.
# 14.	Вычисление статистической значимости различий в среднем количестве заказов на посетителя между группами по «очищенным» данным. Выводы и предположения.
# 15. Построение графиков среднего количества заказов на посетителя между группами по «очищенным» данным. Выводы и предположения.
# 16.	Вычисление статистической значимости различий в среднем чеке заказа между группами по «очищенным» данным. Выводы и предположения.
# 17. Построение графиков среднего чека заказов между группами по «очищенным» данным. Выводы и предположения.
# 18.	Принятие решения по результатам теста и объяснение его.
# Варианты решений:
#     1. Остановить тест, зафиксировать победу одной из групп.
#     2. Остановить тест, зафиксировать отсутствие различий между группами.
#     3. Продолжить тест.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть вступление к проекту - хороший старт. Интересный академический стиль через ДАНО и НАЙТИ - как будто в университет на миг вернулся:)
#
# Спасибо, что есть оглавление в плагине toc - по проекту удобно перемещаться:)

# %% [markdown]
# ## Часть 1. Приоритизация гипотез.

# %% [markdown]
# ### Загрузка данных и получение общей информации о данных ###

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Я вижу, исполнение твоего кода начинается в ячейке с номером, который отличается от единицы. Перед отправкой проекта стоит проверять работоспособность кода — это можно сделать, нажав на панели Jupiter Hub ``Kernel`` и ``Restart & Run All`` (см скриншот ниже).
#
# ![](https://i.postimg.cc/yd19rYf6/Screenshot-428.png)
#
# Важно также убедиться, что все ячейки проекта исполнились - можно просто пролистать работу до конца и убедиться, что последняя ячейка исполнена. Такая проверка поможет тебе убедиться, что твоё решение будет должным образом воспроизведено во время ревью или во время передачи его заказчику - это очень важный этап, пренебрегать которым не стоит:)
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Я всегда так делал, но только через Cell / Run All. И контрольный - пошагово. Через Kernel не делал.
#
# Сделал сейчас. Действительно, все выстроилось с номера 1. Спасибо!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Окей, отлично:)

# %%
hypothesis = pd.read_csv('https://code.s3.yandex.net/datasets/hypothesis.csv') # загрузим csv-файл данных для первой части

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Данные загрузили.
#
# При считывании данных из файла здорово перестраховывать себя от ошибок, связанных, например, с неверным указанием пути к файлу. А иногда бывает, что работаешь с файлом локально, выгружаешь его на сервер, ожидая, что он будет принимать данные, которые лежат на том же сервере, а код падает с ошибкой, потому что путь к файлу не поменялся с локального на серверный.
#
# Для этого, например, можно использовать конструкцию `try-except`: сначала пробуешь локальный путь, при возникновении ошибки используется серверный путь (подробнее можешь почитать тут: https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html).
#
# Но еще лучше использовать библиотеку `os` - её использование позволит тебе отойти от прописывания путей к файлу (а локальные директории могут меняться часто в зависимости от пользователя) и перейти к автоматическому определению пути к файлу с помощью модуля `path`. Как пример:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# В нём мы указываем только непосредственно директорию с файлом, а уже путь к ней модуль `path` определит самостоятельно.
#
# Также ещё на этапе считывания данных можно спарсить дату: за это действие отвечает параметр `parse_dates` метода `read_csv()`, в него нужно передать список с названием полей-дат, и в большинстве случаев дата будет корректно преобразована в нужный формат сразу:)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Очень интересно. Обязательно попробую.
#
#     А если выпадет'Something is wrong', то дальше как? И, Алексей, про дату, пожалуйста, поподробнее или ссылочку.
#     Или это легко гуглиться? Спасибо!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Если выпадает `Something is wrong`, значит, какой-то путь не был найден - нужно искать в нём ошибку или искать файл по этому пути.
#
# Про `parse_dates` - просто параметр метода `pd.read_csv`:
#
#     df = pd.read_csv('https://code.s3.yandex.net/datasets/orders.csv', parse_dates=['date'])

# %%
pd.options.display.max_colwidth = 150
# посмотрим общую инф-цию по этому файлу
print(hypothesis.shape)
hypothesis.info()
display(hypothesis.head(10))
print(hypothesis.columns)
print(hypothesis['Hypothesis'].unique())
# Out:
# (9, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Hypothesis  9 non-null      object
#  1   Reach       9 non-null      int64
#  2   Impact      9 non-null      int64
#  3   Confidence  9 non-null      int64
#  4   Efforts     9 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 488.0+ bytes
#                                                                                                      Hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Стоит настроить отображение гипотез в таблице таким образом, чтобы они отображались в своём столбце целиком - для этого можно настроить параметр `pd.options.display.max_colwidth = 150`.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Замечание реализовал. Принял к сведению. Спасибо!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# **Файл данных в хорошем состоянии. В предобработке не нуждается.**

# %% [markdown]
# ### Фреймворк ICE

# %%
hypothesis['ICE'] =hypothesis['Impact'] * hypothesis['Confidence']/hypothesis['Efforts']
display(round(hypothesis[['Hypothesis', 'ICE']].sort_values(by='ICE', ascending=False), 2))
# Out:
#                                                                                                      Hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Приоритизация по ICE в порядке!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Значение метрики стоит округлить до двух знаков после запятой.
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Замечание реализовал. Спасибо!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ### Фреймворк RICE

# %%
hypothesis['RICE'] =  hypothesis['Reach'] * hypothesis['Impact'] * hypothesis['Confidence']/hypothesis['Efforts']
display(round(hypothesis[['Hypothesis', 'RICE']].sort_values(by='RICE', ascending=False),2))
display(round(hypothesis[['Hypothesis', 'RICE', 'ICE']].sort_values(by=['RICE', 'ICE'], ascending=False),2))
# Out:
#                                                                                                      Hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Приоритизация по RICE выполнена.

# %% [markdown]
# **Приоритизация гипотез во фреймворках ICE и RICE различна. Причиной является использование во фреймворке RICE дополнительного параметра, учитывающего возможную широту охвата потенциальной аудитории планируемым мероприятием. Так оценка широты охвата потенциальных клиентов гипотезой 7 ("Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок") на порядок (в 10 раз) больше, чем оценка широты охвата потенциальных клиентов гипотезой 8 ("Запустить акцию, дающую скидку на товар в день рождения"), при равной оценке трудоемкости равной 5. В связи с учетом большего числа параметров, на мой взгляд, следует отдать предпочтение проритезации гипотез на основе фреймворка RICE. Номера первых пяти гипотез в порядке убывания приоритета во фреймворке RICE - 7, 2, 0, 6, 8.**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Пояснили различия фреймворков, а также интерпретировали различия в приоритетах гипотез - отлично!

# %% [markdown]
# ## Часть 2. Анализ A/B-теста

# %% [markdown]
# ### Загрузка данных и получение общей информации о данных ###

# %%
orders = pd.read_csv('https://code.s3.yandex.net/datasets/orders.csv') # загрузим csv-файл данных для второй части
visitors = pd.read_csv('https://code.s3.yandex.net/datasets/visitors.csv') # загрузим csv-файл данных для второй части
# посмотрим общую инф-цию по этим файлам
print('--'*10, 'dataset "orders" и его параметры', '--'*10)
display(orders.shape)
orders.info()
display(orders.head())
display(orders.columns)

print('orders["date"].min =', orders['date'].min(), ';  orders["date"].max =', orders['date'].max())
print('orders["revenue"].min =', orders['revenue'].min(), ';  orders["revenue"].max =', orders['revenue'].max())
print('orders["group"].unique():', orders['group'].unique())
print('Кол-во явных дублей =', orders.duplicated().sum(), '\n')

# посмотрим распределение покупателей между группами А и В
print('Общее кол-во покупателей:', orders['visitorId'].count())
print('Кол-во покупателей в группе А:', orders[orders['group'] == 'A']['visitorId'].count())
print('Кол-во покупателей в группе В:', orders[orders['group'] == 'B']['visitorId'].count(), '\n')

print('--'*10, 'dataset "visitors" и его параметры', '--'*10)
print(visitors.shape)
visitors.info()
display(visitors.head())
print(visitors.columns)
print('visitors["date"].min =', visitors['date'].min(), ';  visitors["date"].max =', visitors['date'].max())
print('visitors["visitors"].min =', visitors['visitors'].min(), ';  visitors["visitors"].max =', visitors['visitors'].max())
print('visitors["group"].unique():', visitors['group'].unique())
print('Кол-во явных дублей =', visitors.duplicated().sum(), '\n')
# посмотрим распределение пользователей между группами А и В
print('Общее кол-во пользователей:', visitors['visitors'].sum())
print('Кол-во пользователей в группе А:', visitors[visitors['group'] == 'A']['visitors'].sum())
print('Кол-во пользователей в группе В:', visitors[visitors['group'] == 'B']['visitors'].sum(), '\n')

# приведем значения дат к типу "datetime64"
orders['date'] = orders['date'].astype('datetime64')
visitors['date'] = visitors['date'].astype('datetime64')
print('Даты в столбцах orders["date"], visitors["date"] приведены к типу:', orders['date'].dtype, visitors['date'].dtype)
# Out:
# -------------------- dataset "orders" и его параметры --------------------
# (1197, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   object
#  3   revenue        1197 non-null   int64
#  4   group          1197 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB
#    transactionId   visitorId        date  revenue group
# 0     3667963787  3312258926  2019-08-15     1650     B
# 1     2804400009  3642806036  2019-08-15      730     B
# 2     2961555356  4069496402  2019-08-15      400     A
# 3     3797467345  1196621759  2019-08-15     9759     B
# 4     2282983706  2322279887  2019-08-15     2308     B
# Index(['transactionId', 'visitorId', 'date', 'revenue', 'group'], dtype='object')
# ...

# %% [markdown]
# **Данные представлены в хорошем состоянии. Кроме приведения дат к типу "datetime64[ns]" необходимость иной предобработки не выявлена.**
#
# **Пользователи распределены между группами А и В довольно равномерно, различие составляет менее 0,5% (0,478%).**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Загрузили данные о покупателях и посетителях, выполнили анализ и предобработку - отлично!

# %% [markdown]
# ### Проверка выборок групп А и В на пересечение. Фильтрация пересечений.

# %%
# проверим наличие покупателей, вошедших в обе группы А и В
visitorId_orders_A = orders[orders['group'] == 'A']['visitorId']
visitorId_orders_B = orders[orders['group'] == 'B']['visitorId']
visitorId_orders_AB = orders.query('(visitorId in @visitorId_orders_A) & (visitorId in @visitorId_orders_B)')['visitorId']
print('visitorId, попавшие в обе группы:', len(visitorId_orders_AB.unique()),'\n')

# создадим срез "orders" по покупателям, вошедших в обе группы А и В
orders_intersect = orders.query('visitorId in @visitorId_orders_AB')[['transactionId', 'visitorId', 'date', 'revenue', 'group']]
display('orders_intersect', orders_intersect)

# посмотрим на кол-во заказов у покупателей, вошедших в обе группы А и В
display('Пересекающиеся покупатели - кол-во заказов', orders_intersect.groupby('visitorId', as_index=False)
        .agg({'transactionId':'count', 'revenue':'sum'})
        .sort_values(by='transactionId', ascending=False))
# посмотрим на суммы заказов у покупателей, вошедших в обе группы А и В
display('Пересекающиеся покупатели - сумма заказов', orders_intersect.groupby('visitorId', as_index=False)
      .agg({'transactionId':'count', 'revenue':'sum'})
      .sort_values(by='revenue', ascending=False))
# посмотрим доли покупателей, вошедших в обе группы А и В, в численном составе, кол-ве заказов и суммах заказов
print('{0:.2%}'.format(len(orders_intersect['visitorId'].unique())/len(orders['visitorId'].unique())),\
      '- доля пересекающихся покупателей в составе')
print('{0:.2%}'.format(orders_intersect['transactionId'].count()/orders['transactionId'].count()),
'- доля пересекающихся покупателей в кол-ве заказов')
print('{0:.2%}'.format(orders_intersect['revenue'].sum()/orders['revenue'].sum()),
      '- доля пересекающихся покупателей в суммах заказов \n')

# создадим фрейм с мультиндексом 'date', 'group' и кол-вом покупателей, вошедших в обе группы А и В, на эти дату и группу
dates_group_N_intersect = orders_intersect.groupby(['date', 'group'])['visitorId'].count()
# приведем дата фрейм "visitors" к такому же виду с мультиндексом 'date', 'group'
visitors_dates_group = visitors.groupby(['date', 'group'])['visitors'].sum()

# получим новую таблицу "visitors" с вычтенными кол-вами покупателей, вошедших в обе группы А и В, по каждой дате и группе
visitors_new = visitors_dates_group.sub(dates_group_N_intersect, fill_value=0).reset_index()
visitors_new.columns = ['date', 'group', 'visitors'] 
print(visitors_new)

# сохраним исходные датасеты "orders" и "visitors" в копиях
orders_copy = orders
visitors_copy = visitors
# удалим из "orders" и "visitors" покупателей, вошедших в обе группы, как ошибочные
orders = orders.query('visitorId not in @visitorId_orders_AB')
visitors = visitors_new

# посмотрим общую инф-цию по отфильтрованному файлу "orders"
print('--'*10, 'отфильтрованный "orders" (без покупателей, вошедших в обе группы) и его параметры', '--'*10)
display(orders.shape)
orders.info()
print('orders["date"].min =', orders['date'].min(), ';  orders["date"].max =', orders['date'].max())
print('orders["revenue"].min =', orders['revenue'].min(), ';  orders["revenue"].max =', orders['revenue'].max())
print('orders["group"].unique():', orders['group'].unique())
print('Кол-во явных дублей =', orders.duplicated().sum(), '\n')
# посмотрим распределение покупателей между группами А и В
print('Общее кол-во покупателей:', orders['visitorId'].count())
print('Кол-во покупателей в группе А:', orders[orders['group'] == 'A']['visitorId'].count())
print('Кол-во покупателей в группе В:', orders[orders['group'] == 'B']['visitorId'].count(), '\n')
# проверим наличие покупателей, вошедших в обе группы А и В
visitorId_orders_A_2 = orders[orders['group'] == 'A']['visitorId']
visitorId_orders_B_2 = orders[orders['group'] == 'B']['visitorId']
visitorId_orders_AB_2 = orders.query('(visitorId in @visitorId_orders_A_2) & (visitorId in @visitorId_orders_B_2)')['visitorId']
print('visitorId, попавшие в обе группы:', visitorId_orders_AB_2.count(),'\n')

# посмотрим общую инф-цию по отфильтрованному файлу "visitors"
print('--'*10, 'отфильтрованный "visitors" (без покупателей, вошедших в обе группы) и его параметры', '--'*10)
print('Общее кол-во пользователей:', visitors['visitors'].sum())
print('Кол-во пользователей в группе А:', visitors[visitors['group'] == 'A']['visitors'].sum())
print('Кол-во пользователей в группе В:', visitors[visitors['group'] == 'B']['visitors'].sum(), '\n')
# Out:
# visitorId, попавшие в обе группы: 58
# 'orders_intersect'
#       transactionId   visitorId       date  revenue group
# 2        2961555356  4069496402 2019-08-15      400     A
# 20       2904772834   963407295 2019-08-15      300     B
# 23       4252514150   351125977 2019-08-15    15185     B
# 24       1162046357  3234906277 2019-08-15     7555     B
# 26       2223239646   199603092 2019-08-15     3488     A
# ...             ...         ...        ...      ...   ...
# 1182     2682156369  1668030113 2019-08-14     1290     B
# 1183     1458356232   963407295 2019-08-14     4940     A
# 1184     1329499668  2949041841 2019-08-14    10380     B
# 1189     4082620617   393266494 2019-08-14    31550     B
# 1195     1947021204  1614305549 2019-08-14      100     A
#
# [181 rows x 5 columns]
# 'Пересекающиеся покупатели - кол-во заказов'
#      visitorId  transactionId  revenue
# 56  4256040402             11   176490
# 27  2458001652             11    62098
# ...

# %% [markdown]
# **Проверка выявила 181 покупателя, входящих как в состав группы А, так и в состав группы В.  При этом
# 5,63% - доля в численном составе покупателей,
# 15,12% - доля в кол-ве заказов,
# 15,60% - доля в суммах заказов,
# 0,48% - доля в общей выборке.
# Несмотря на незначительную долю в общей выборке пользователей, доля пересекающихся покупателей в общем числе покупателей, заказов и сумм достаточно существенна и может оказать влияние на результаты теста.
# Так же из среза по пересекающимся покупателям, отсортированном по кол-ву заказов и по сумме заказов, и из долей в численном составе,  в кол-ве и сумм заказов пересекающихся покупателей видно, что пересекающиеся покупатели являются источником "тяжелых хвостов", аномальных по величине значений и будут в значительной своей части в дальнейшем все-равно отсеяны при фильтрации аномальных значений.
# Таким образом, было принято решение о фильтрации пользователей, относящихся к пересекающимся покупателям.**

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Идея проверить пересечение между пользователями по группам - шикарная, но реализация чуть подвела: выполняя код `visitorId_orders_AB = orders.query('(visitorId in @visitorId_orders_A) & (visitorId in @visitorId_orders_B)')['visitorId']`, ты находишь не уникальных пользователей, а строки из таблицы `orders` с теми пользователями, которые имеют пересечения. Для корректной фильтрации стоит вывести количество именно уникальных пользователей из пересечения и уже по этим пользователям выполнять фильтрацию, удаляя их.
#
#     <div class="alert alert-info">
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Согласен. Это срез операций пересекающихся пользователей. Именно он нужен и именно в таком виде далее используется. Ошибкой было назвать число строк этого среза числом покупателей. Это, конечно, неверно. Но далее доля в численном составе посчитана по уникальным Id. Иначе доли просто не отличались бы. А первый вывод с кол-вом пересекающихся покупателей =181 это неверно. 181 заказ у 58 пересекающихся пользователей. Дальнейших последствий данная ошибка не имела.
#     Ошибку исправил. Замечание реализовано. Спасибо!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В целом ошибка имела место, так как удаление было реализован по индексам - это сдвигало количество покупок и приводило бы к неправильному расчёту персентилей. Теперь порядок.

# %% [markdown]
# ### Построение графика кумулятивной выручки по группам. Выводы и предположения.

# %%
# строим массив уникальных пар значений дат и групп
dates_groups = orders[['date', 'group']].drop_duplicates().sort_values(by=['date', 'group'])

# агрегируем таблицу "orders"
orders_agregg = dates_groups.apply(
    lambda x:orders[
        np.logical_and(orders['date'] <= x['date'], orders['group'] == x['group'])
                    ]
        .agg({'date':'max', 'group':'max', 'visitorId':'nunique', 'transactionId':'nunique', 'revenue':'sum'}), axis=1
                                    )\
        .sort_values(by=['date', 'group'])
# присваиваем столбцам более понятные названия в таблице "orders_agregg"
orders_agregg.columns = ['date', 'group', 'cum_N_buyers', 'cum_N_orders', 'cum_revenue']  

display('Агрегированная таблица orders_agregg:', orders_agregg.head())
orders_agregg.info()

# датафрейм с кумулятивными данными по дням в группе А
orders_agregg_A = orders_agregg[orders_agregg['group'] == 'A']
# датафрейм с кумулятивными данными по дням в группе А
orders_agregg_B = orders_agregg[orders_agregg['group'] == 'B']

print('Кол-во элементов orders_agregg_A:', orders_agregg_A['group'].count())
print('Кол-во элементов orders_agregg_B:', orders_agregg_B['group'].count())

plt.figure(figsize=(14,7))
plt.grid()
# строим график кумулятивной выручки группы А
plt.plot(orders_agregg_A['date'], orders_agregg_A['cum_revenue'], label='A')
# строим график кумулятивной выручки группы В
plt.plot(orders_agregg_B['date'], orders_agregg_B['cum_revenue'], label='B')
plt.legend()
plt.title('Графики кумулятивной выручки по группам', fontsize=18, color='blue')
plt.ylabel('Выручка, $*100000', fontsize=15, color='blue')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Даты', fontsize=15, color='blue')
plt.show()
# Out:
# 'Агрегированная таблица orders_agregg:'
#           date group  cum_N_buyers  cum_N_orders  cum_revenue
# 55  2019-08-01     A            19            23       142779
# 66  2019-08-01     B            17            17        59758
# 175 2019-08-02     A            36            42       234381
# 173 2019-08-02     B            39            40       221801
# 291 2019-08-03     A            60            66       346854
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62 entries, 55 to 930
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          62 non-null     datetime64[ns]
#  1   group         62 non-null     object
#  2   cum_N_buyers  62 non-null     int64
#  3   cum_N_orders  62 non-null     int64
#  4   cum_revenue   62 non-null     int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 2.9+ KB
# Кол-во элементов orders_agregg_A: 31
# Кол-во элементов orders_agregg_B: 31

# %% [markdown]
# **Из графиков видно, что 2019-08-19 происходит скачок в кумулятивной выручке в группе В, что может объясняться аномальным кол-вом заказов в этот день или наличием заказа с аномально большой суммой. В связи с наличием аномальных значений нельзя сделать обоснованные выводы о наличии различий в кумулятивной выручке в разных группах. Необходима фильтрация аномальных значений.**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Тут всё верно.

# %% [markdown]
# ### Построение графика кумулятивного среднего чека по группам.  Выводы и предположения.

# %%
plt.figure(figsize=(14,7))
plt.grid()
# строим график кумулятивного среднего чека группы А
plt.plot(orders_agregg_A['date'], orders_agregg_A['cum_revenue']/orders_agregg_A['cum_N_orders'], label='A')
# строим график кумулятивного среднего чека группы В
plt.plot(orders_agregg_B['date'], orders_agregg_B['cum_revenue']/orders_agregg_B['cum_N_orders'], label='B')
plt.legend()
plt.title('Графики кумулятивного среднего чека по группам', fontsize=18, color='blue')
plt.ylabel('Выручка, $', fontsize=15, color='blue')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Даты', fontsize=15, color='blue')
plt.show()

# %% [markdown]
# **Аналогично предыдущему графику видим, что 2019-08-19 происходит скачок в кумулятивном среднем чеке в группе В, что может объясняться той же причиной - аномальным кол-вом заказов в этот день или наличием заказа с аномально большой суммой. В связи с наличием аномальных значений нельзя сделать обоснованные выводы о наличии различий в кумулятивном среднем чеке в разных группах. Необходима фильтрация аномальных значений.**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошо.

# %% [markdown]
# ### Построение графика относительного изменения кумулятивного среднего чека группы B к группе A.  Выводы и предположения.

# %%
# создадим единую таблицу "orders_agregg_АВ" на основе "orders_agregg_А" и "orders_agregg_B"
orders_agregg_AB = orders_agregg_A.merge(orders_agregg_B, left_on='date', right_on='date', how='left', suffixes=['A','B'])

plt.figure(figsize=(14,7))
plt.grid()
# строим график относительного изменения кумулятивного среднего чека группы B к группе A
plt.plot(orders_agregg_AB['date'], (orders_agregg_AB['cum_revenueB']/orders_agregg_AB['cum_N_ordersB'])\
         /(orders_agregg_AB['cum_revenueA']/orders_agregg_AB['cum_N_ordersA']) - 1, label='(B/A - 1)')
plt.legend()
plt.title('График относительного изменения кумулятивного среднего чека группы B к группе A', fontsize=18, color='blue')
#plt.ylabel('Выручка, $', fontsize=15, color='blue')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Даты', fontsize=15, color='blue')
#plt.axhline(y=0.2, color='green', linestyle='--')
plt.axhline(y=0, color='black', linestyle='-')
plt.show()

# %% [markdown]
# **Картина подобная предыдущим. Видим колебания начального периода, аномальное значение кумулятивного среднего чека, приходящееся на 2019-08-19. В связи с наличием аномальных значений нельзя сделать обоснованные выводы о наличии различий в кумулятивном среднем чеке в разных группах. Необходима фильтрация аномальных значений.**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Верно.

# %% [markdown]
# ### Построение графика кумулятивного среднего количества заказов на посетителя по группам.  Выводы и предположения.

# %%
# агрегируем таблицу "visitors"
visitors_agregg = dates_groups.apply(
    lambda x:visitors[
        np.logical_and(visitors['date'] <= x['date'], visitors['group'] == x['group'])
                    ]
        .agg({'date':'max', 'group':'max', 'visitors':'sum'}), axis=1
                                    )\
        .sort_values(by=['date', 'group'])
# присваиваем столбцам более понятные названия в таблице "visitors_agregg"
visitors_agregg.columns = ['date', 'group', 'cum_N_visitors']  

# посмотрим, что получилось
display(visitors_agregg.head())
visitors_agregg.info()

# создадим единую таблицу "orders_agregg" на основе "orders_agregg" и "visitors_agregg"
orders_visitors_agregg = orders_agregg.merge(visitors_agregg, left_on=['date', 'group'], right_on=['date', 'group'], how='left')

# посмотрим, что получилось
display(orders_visitors_agregg.head())
orders_visitors_agregg.info()

# датафрейм с кумулятивными данными по дням в группе А
orders_visitors_agregg_A = orders_visitors_agregg[orders_visitors_agregg['group'] == 'A']
# датафрейм с кумулятивными данными по дням в группе А
orders_visitors_agregg_B = orders_visitors_agregg[orders_visitors_agregg['group'] == 'B']

plt.figure(figsize=(14,7))
plt.grid()
# строим график кумулятивного среднего количества заказов на посетителя группы А
plt.plot(orders_visitors_agregg_A['date'], orders_visitors_agregg_A['cum_N_orders']/orders_visitors_agregg_A['cum_N_visitors'],\
         label='A')
# строим график кумулятивного среднего количества заказов на посетителя группы В
plt.plot(orders_visitors_agregg_B['date'], orders_visitors_agregg_B['cum_N_orders']/orders_visitors_agregg_B['cum_N_visitors'],\
         label='B')
plt.legend()
plt.title('Графики кумулятивного среднего количества заказов на посетителя по группам', fontsize=18, color='blue')
plt.ylabel('Кумулятивное среднее кол-во заказов на посетителя', fontsize=15, color='blue')
plt.xticks(rotation=45, ha='right')
plt.axhline(y=0.0290, color='red', linestyle='dotted')
plt.axhline(y=0.0255, color='green', linestyle='dotted')
plt.xlabel('Даты', fontsize=15, color='blue')
plt.show()
# Out:
#           date group  cum_N_visitors
# 55  2019-08-01     A           718.0
# 66  2019-08-01     B           709.0
# 175 2019-08-02     A          1336.0
# 173 2019-08-02     B          1289.0
# 291 2019-08-03     A          1843.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62 entries, 55 to 930
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            62 non-null     datetime64[ns]
#  1   group           62 non-null     object
#  2   cum_N_visitors  62 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 1.9+ KB
#         date group  cum_N_buyers  cum_N_orders  cum_revenue  cum_N_visitors
# 0 2019-08-01     A            19            23       142779           718.0
# 1 2019-08-01     B            17            17        59758           709.0
# 2 2019-08-02     A            36            42       234381          1336.0
# ...

# %% [markdown]
# **1. На графиках видим колебания начального периода, которые с течением времени уменьшаются и ориентировочно стремятся к некоторым устоявшимся значениям, которые указаны пунктирными линиями. Данные значения не рассчитаны, а построены, исходя из графиков, т.е. "на глазок", в качестве ориентира. Уровни примерно соответствуют 0,0255 и 0,0290, разница составляет 0,0035 или ~ 14%. Можно ожидать такого различия в кумулятивном среднем количества заказов на посетителя между группами, т.е. кумулятивное среднее количества заказов на посетителя группы B на 14% больше кумулятивного среднего количества заказов на посетителя группы A.**
#
# **2. Следует отметить, что на этих графиках нет выброса в значениях на 2019-08-19. Из чего можно сделать вывод, что аномальное значение приходится не на кол-во заказов, а на сумму заказа(-ов) от 2019-08-19.**
#
# **3. Среднее количество заказов на посетителя - это не конверсия, но в нашем случае, это очень близко к ней. Поэтому представляется интересным оценить достаточность размера выборки и длительности теста с помощью "калькуляторов конверсии". Проверка размеров выборки и длительности теста на калькуляторах конверсии (http://www.evanmiller.org/ab-testing/sample-size.html и https://vwo.com/tools/ab-test-duration-calculator/ ) показала, что при
# начальной конверсии ~ 2,5%
# уровня значимости 5%
#  уровня мощности критерия 80%
#  для регистрации отклонения в 13% необходима выборка в 36 905 элементов, для отклонения в 15% - 27 797 элементов.
#  Аналогично, проверка длительности теста показала, что при
#  начальной конверсии ~ 2,5%
#  числе вариаций 1
#  среднем числе посещений в день 1214
#  процент посетителей, вкл-ых в тест 100%
#  для регистрации отклонения в 13% необходима длительность теста в 30 дней, для отклонения в 15% - 23 дня.
#  Таким образом, по оценке калькуляторов конверсии, при начальной конверсии ~ 2,5% регистрируемое изменение в конверсии по данной выборке (37 652 элемента, длительность теста 31 день) должно быть от 13%. Для регистрации отклонений менее 13% размер выборки и длительность теста должны быть больше.
#  Полученные результаты вписываются в представление о достаточности выборки и длительности теста. Однако все-таки необходимо отметить, что ситуация пограничная.**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Глубоко копнул - молодец! Тут всё хорошо.

# %% [markdown]
# ### Построение графика относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A.  Выводы и предположения.

# %%
# создадим единую таблицу "orders_visitors_agregg_АВ" на основе "orders_visitors_agregg_А" и "orders_visitors_agregg_B"
orders_visitors_agregg_AB = orders_visitors_agregg_A.merge(orders_visitors_agregg_B, left_on='date', right_on='date', \
                                                           how='left', suffixes=['A','B'])

plt.figure(figsize=(14,7))
plt.grid()
# строим график относительного изменения кумулятивного количества заказов на посетителя группы B к группе A
plt.plot(orders_visitors_agregg_AB['date'], (orders_visitors_agregg_AB['cum_N_ordersB']/orders_visitors_agregg_AB['cum_N_visitorsB'])\
         /(orders_visitors_agregg_AB['cum_N_ordersA']/orders_visitors_agregg_AB['cum_N_visitorsA']) - 1, label='(B/A - 1)')
plt.legend()
plt.title('График относительного изменения кумулятивного количества заказов на посетителя группы B к группе A', \
          fontsize=18, color='blue')
#plt.ylabel('Выручка, $', fontsize=15, color='blue')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Даты', fontsize=15, color='blue')
plt.axhline(y=0.14, color='green', linestyle='--')
plt.axhline(y=0, color='black', linestyle='-')
plt.show()

# %% [markdown]
# **График относительного изменения кумулятивного количества заказов на посетителя группы B к группе A демонстрирует то же самое, что и предыдущие графики кумулятивного среднего количества заказов на посетителя групп А и B. На графике видим колебания начального периода, которые с течением времени уменьшаются и ориентировочно стремятся к некоторому устоявшемуся значению, которое указано пунктирной линией. Данное значения не рассчитано, а построено, исходя из графика, т.е. "на глазок", в качестве ориентира. Уровень примерно соответствуют 0,14. Можно ожидать такого различия в кумулятивном среднем количества заказов на посетителя между группами, т.е. кумулятивное среднее количества заказов на посетителя группы B на 14 % больше кумулятивного среднего количества заказов на посетителя группы A.**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Здесь тоже всё верно - отличная работа.

# %% [markdown]
# ### Построение точечного графика количества заказов по пользователям.  Выводы и предположения.

# %%
# создадим таблицу с кол-вом заказов по каждому пользователю
visitors_transactions = orders.groupby('visitorId')['transactionId'].count().sort_values(ascending=False).reset_index()
display(visitors_transactions)
visitors_transactions.columns = ['visitorId', 'N_transactions']

# построим точечный график количества заказов по пользователям
plt.figure(figsize=(14,7))
plt.grid()
plt.scatter(visitors_transactions['visitorId'],visitors_transactions['N_transactions'])
plt.title('Точечный график количества заказов по пользователям', \
          fontsize=18, color='green')
plt.ylabel('Кол-во заказов, шт', fontsize=15, color='green')
plt.xlabel('ID Пользователей', fontsize=15, color='green')
plt.show()
# Out:
#       visitorId  transactionId
# 0    3967698036              3
# 1     249864742              3
# 2    2108163459              3
# 3    2988190573              3
# 4    3908431265              3
# ..          ...            ...
# 968  1438226485              1
# 969  1452540367              1
# 970  1455323168              1
# 971  1455861274              1
# 972  4283872382              1
#
# [973 rows x 2 columns]

# %% [markdown]
# **Точечный график количества заказов по пользователям показывает, что довольно много пользователей с 2-3 заказами. Их точная доля не ясна — непонятно, считать их аномалиями или нет. Следует посчитать перцентили.**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Проанализировали распределение количества покупок на пользователя и нашли аномальных покупателей - отлично!

# %% [markdown]
# ### Вычисление 95-го и 99-го перцентилей количества заказов на пользователя. Выбор границы для определения аномальных пользователей.

# %%
print(np.percentile(visitors_transactions['N_transactions'], [90, 95, 99]))
# Out:
# [1. 1. 2.]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Персентили посчитаны верно.

# %% [markdown]
# **Таким образом,**
# **- больше 1-го заказа сделало не более 5% пользователей,**
# **- больше 2-х заказов сделало не более 1% пользователей,**
# **Выберем 1 заказ на одного пользователя за верхнюю границу числа заказов, и отсеим аномальных пользователей с большим числом заказов (которых не более 5%).**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Определили границу для фильтрации аномалий - отлично!

# %% [markdown]
# ### Построение точечного графика стоимостей заказов по пользователям.  Выводы и предположения.

# %%
# создадим таблицу с суммой заказов по каждому пользователю
visitors_revenue = orders.groupby('visitorId')['revenue'].sum().sort_values(ascending=False).reset_index()
display(visitors_revenue)
visitors_revenue.columns = ['visitorId', 'sum_revenue']

# построим точечный график стоимостей заказов по пользователям
plt.figure(figsize=(14,7))
plt.grid()
plt.scatter(visitors_revenue['visitorId'],visitors_revenue['sum_revenue'])
plt.title('Точечный график стоимостей заказов по пользователям', \
          fontsize=18, color='green')
plt.ylabel('Сумма заказов, $*1000000', fontsize=15, color='green')
plt.xlabel('ID Пользователей', fontsize=15, color='green')
plt.show()

print('Параметры аномального заказа\n', orders[orders['revenue'] == 1294500])

plt.figure(figsize=(14,7))
plt.grid()
visitors_revenue_supr = visitors_revenue.query('sum_revenue <= 200000')
plt.scatter(visitors_revenue_supr['visitorId'],visitors_revenue_supr['sum_revenue'])
plt.title('Точечный график стоимостей заказов < $200 000 по пользователям', \
          fontsize=18, color='green')
plt.ylabel('Сумма заказов, $', fontsize=15, color='green')
plt.xlabel('ID Пользователей', fontsize=15, color='green')
plt.show()
# Out:
#       visitorId  revenue
# 0    1920142716  1294500
# 1    2108080724   202740
# 2    1307669133    92550
# 3     888512513    86620
# 4     759473111    72000
# ..          ...      ...
# 968  1995481842       70
# 969  3577713868       60
# 970  2738601405       50
# 971  2705308997       50
# 972  3423937755       50
#
# [973 rows x 2 columns]
# Параметры аномального заказа
#       transactionId   visitorId       date  revenue group
# 425      590470918  1920142716 2019-08-19  1294500     B

# %% [markdown]
# **Точечный график стоимостей заказов по пользователям выявил аномальный заказ от 2019-08-19 на сумму 1 294 500 USD, следствием которого и являлся сдвиг в графиках пп.3.2-3.4. Точечный график стоимостей заказов по пользователям без этого аномального значения (стоимость заказа < 200 000 USD) показывает, что основная сумма заказов до 30 000 USD. Есть небольшое кол-во заказов в диапазоне 30 000 - 100 000 долл, их точная доля не ясна — непонятно, считать их аномалиями или нет. Следует посчитать перцентили.**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Проанализировали распределение стоимости заказов и нашли аномально дорогие заказы - отлично! Круто, что сделал дополнительный график без учёта двух крупных выбросов.

# %% [markdown]
# ### Вычисление 95-го и 99-го перцентилей стоимостей заказов на пользователя. Выбор границы для определения аномальных пользователей.

# %%
print(np.percentile(visitors_revenue['sum_revenue'], [90, 95, 99]))
# Out:
# [18236. 28910. 59082.]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Персентили посчитаны верно.

# %% [markdown]
# **Таким образом,**
# **- заказ с суммой больше 18 000 долл сделало не более 10% пользователей,**
# **- заказ с суммой больше 29 000 долл сделало не более 5% пользователей,**
# **- заказ с суммой больше 59 000 долл сделало не более 1% пользователей.**
# **Выберем сумму заказа равную 29 000 долл за верхнюю границу стоимости заказов, и отсеим аномальных пользователей с большей суммой заказов (которых не более 5%).**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Определили границу для фильтрации аномалий - отлично!

# %% [markdown]
# ### Вычисление статистической значимости различий в среднем количестве заказов на посетителя между группами по «сырым» данным. Выводы и предположения.

# %% [markdown]
# **Сформулируем гипотезы.
# Нулевая: различий в среднем количестве заказов между группами B и А нет.
# Альтернативная: различия в среднем количестве заказов между группами B и А есть.**
#
# **Прежде, чем перейти к выбору критерия, по которому будем оценивать статистическую значимость различий, построим гистограммы выборок и проверим их на соответствие нормальному распределению по критерию Шапиро-Уилка, что связано с тем фактом, что очень многие параметрические критерии оценки статистической значимости требуют близости выборок или исходных генеральных совокупностей к нормальному распределению.
# Для "visitors_transactions_A(В)" гистограмма ближе к дельта-функции, чем к колоколу нормального распределения, а критерий Шапиро-Уилка (p-значение = 7.67e-40) не оставляет шансов на нормальность.
# Для выборки "visitors" гистограмма несколько нормальнее, но только при либеральном критерии значимости в 1% эту выборку можно признать нормальной по критерию Шапиро-Уилка (p-значение = 0.023).
# Именно в связи с ненормальностью представленных выборок для определения статистической значимости различий между группами будет использован U-критерий Манна-Уитни. U-критерий Манна-Уитни – это непараметрический статистический критерий, который используется для сравнения выраженности показателей в двух несвязных выборках. Непараметрические критерии менее точные, но зато у них нет жестких требований к данным. Эти данные могут быть почти любыми.Что значит несвязные выборки? Это означает, что группы не пересекаются, то есть в них разные испытуемые. Многие критерии имеют модификации для связных выборок, критерий Манна-Уитни используется только для несвязных. Поэтому при его использовании важно проверять выборки на отсутствие пересечений.
# Справедливости ради надо отметить, что несмотря на широкое использование U-критерия Манна-Уитни в прикладных задачах, есть работы, ставящие под сомнение эффективность и даже применимость этого критерия на практике, например https://habr.com/ru/company/avito/blog/709596/. Но на примере данных этой работы критерий Манна-Уитни, на мой взгляд, отработал шикарно.**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Гипотезы сформулированы - отлично!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Важно также указать критерий, с помощью которого мы проверяем гипотезы, а также обосновать его выбор - это обычно связано с наличием в данных каких-то особенностей и характером их распределения (про это говорилось в тренажёре).
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# К сформулированным гипотезам добавил обоснование выбора метода оценки статистической значимости.
#
#   Замечание реализовано.
#
#     Алексей, какое твое отношение к критерию Манна-Уитни? И какой должна быть несвязность? Абсолютной? Или, скажем, не более 15% и какого параметра - общей численности или выручки, или еще чего?
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено. Мало когда применял на практике этот критерий - обычно выравнивал распределение бутстрапом и использовал `ttest`. По поводу несвязности - абсолютную мало когда можно найти, если прям честно-честно несвязность рассматривать. Поэтому обычно есть какие-то допущения. Какие - зависит от эксперимента, всё индивидуально.

# %%
# создадим таблицу с кол-вом заказов по каждому пользователю в группе А
visitors_transactions_A = orders[orders['group'] == 'A'].groupby('visitorId', as_index=False)['transactionId'].count()
visitors_transactions_A.columns = ['visitorId', 'N_transactions']
print('Уникальные значения visitors_transactions_A:', sorted(visitors_transactions_A['N_transactions'].unique()))

# создадим таблицу с кол-вом заказов по каждому пользователю в группе B
visitors_transactions_B = orders[orders['group'] == 'B'].groupby('visitorId', as_index=False)['transactionId'].count()
visitors_transactions_B.columns = ['visitorId', 'N_transactions']
print('Уникальные значения visitors_transactions_B:', sorted(visitors_transactions_B['N_transactions'].unique()))

display('visitors_transactions_A:', visitors_transactions_A, 'visitors_transactions_B:', visitors_transactions_B)

# ------------------------------------------------------------------------
print('--'*10, 'ГИСТОГРАММЫ "visitors_transactions_A" и "visitors"')
plt.hist(visitors_transactions_A['N_transactions'], bins=3, color='gray', label='visitors_transactions_A')
plt.legend()
plt.show()
print('p-значение критерия Шапиро-Уилка: ', round(st.shapiro(visitors_transactions_A['N_transactions'])[1], 42))

plt.hist(visitors.groupby('date')['visitors'].sum(), bins=7, color='gray', label='visitors')
plt.legend()
plt.show()
print('p-значение критерия Шапиро-Уилка: ', round(st.shapiro(visitors.groupby('date')['visitors'].sum())[1], 3), '\n')
# -----------------------------------------------------------------------------

# подсчитаем кол-во нулей, которые нужно добавить для формирования выборки к проверке критерием Манна-Уитни
t1 = len(visitors_transactions_A['visitorId'])
t2 = visitors[visitors['group'] == 'A']['visitors'].sum()
N_zero_A = t2 - t1
print(' t1 - Кол-во покупателей в группе;', '\n',
      't2 - Общее кол-во пользователей в группе;', '\n', 
      'N_zero_ - Кол-во нулей, добавляемое в выборку группы;', '\n')
print('t1 =', t1, '   t2 =', t2, '   N_zero_A =', N_zero_A)

t1 = len(visitors_transactions_B['visitorId'])
t2 = visitors[visitors['group'] == 'B']['visitors'].sum()
N_zero_B = t2 - t1
print('t1 =', t1, '   t2 =', t2, '   N_zero_B =', N_zero_B)

# формируем выборку по группе А к проверке критерием Манна-Уитни
sample_A = pd.concat([visitors_transactions_A['N_transactions'],pd.Series(0,index=np.arange(N_zero_A), \
                                                                         name='transactions')],axis=0)
# формируем выборку по группе В к проверке критерием Манна-Уитни
sample_B = pd.concat([visitors_transactions_B['N_transactions'],pd.Series(0,index=np.arange(N_zero_B), \
                                                                         name='transactions')],axis=0)
display(sample_A, sample_B)

print('p-value = ', round(st.mannwhitneyu(sample_A, sample_B)[1], 5))
print('Относительный прирост среднего числа заказов группы B =','{0:.2%}'.format(sample_B.mean()/sample_A.mean()- 1))
# Out:
# Уникальные значения visitors_transactions_A: [1, 2, 3]
# Уникальные значения visitors_transactions_B: [1, 2, 3]
# 'visitors_transactions_A:'
#       visitorId  N_transactions
# 0      11685486               1
# 1      54447517               1
# 2      66685450               1
# 3      78758296               1
# 4      85103373               1
# ..          ...             ...
# 440  4227830084               1
# 441  4237561104               1
# 442  4243832526               1
# 443  4259830713               1
# 444  4278982564               1
#
# [445 rows x 2 columns]
# 'visitors_transactions_B:'
#       visitorId  N_transactions
# 0       5114589               1
# 1       6958315               1
# 2      39475350               1
# 3      47206413               1
# 4      48147722               1
# ..          ...             ...
# 523  4251115836               1
# 524  4258103007               1
# 525  4279090005               1
# 526  4281247801               1
# ...

# %% [markdown]
# **По "сырым" данным получаем следующую оценку статистической значимости наличия различий между группами В и А.**
#
# **При пороге значимости а = 0,05 нулевую гипотезу о том, что статистически значимых различий в среднем числе заказов между группами А и В нет, - отвергаем. Выбираем альтернативную гипотезу: различия в среднем числе заказов между группами B и А есть. При этом относительный прирост среднего числа заказов группы B равен примерно 16%.**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Оценили значимость различий среднего количества заказов на посетителя между группами на сырых данных - отлично!

# %% [markdown]
# ### Вычисление статистической значимости различий в среднем чеке заказа между группами по «сырым» данным. Выводы и предположения.

# %% [markdown]
# **Сформулируем гипотезы.
# Нулевая: различий в среднем чеке заказов между группами B и А нет.
# Альтернативная: различия в среднем чеке заказов между группами B и А есть.**

# %%
# создадим таблицу с суммой заказов по каждому пользователю в группе А
visitors_revenue_A = orders[orders['group'] == 'A'].groupby('visitorId', as_index=False)[['revenue', 'transactionId']]\
.agg({'revenue':'sum', 'transactionId':'count'})
visitors_revenue_A.columns = ['visitorId', 'sum_revenue', 'N_transaction']

# создадим таблицу с кол-вом заказов по каждому пользователю в группе B
visitors_revenue_B = orders[orders['group'] == 'B'].groupby('visitorId', as_index=False)[['revenue', 'transactionId']]\
.agg({'revenue':'sum', 'transactionId':'count'})
visitors_revenue_B.columns = ['visitorId', 'sum_revenue', 'N_transaction']

display('visitors_revenue_A:', visitors_revenue_A.sort_values(by='N_transaction', ascending=False),\
        'visitors_revenue_B:', visitors_revenue_B.sort_values(by='N_transaction', ascending=False))

print('p-value = ', round(st.mannwhitneyu(visitors_revenue_B['sum_revenue'],visitors_revenue_A['sum_revenue'])[1], 5))
print('p-value = ', round(st.mannwhitneyu(visitors_revenue_B['sum_revenue']/visitors_revenue_B['N_transaction'],\
                                           visitors_revenue_A['sum_revenue']/visitors_revenue_A['N_transaction'])[1], 5))
print('Относительный прирост среднего чека заказов группы B =','{0:.2%}'\
      .format(visitors_revenue_B['sum_revenue'].mean()/visitors_revenue_A['sum_revenue'].mean()- 1))
# Out:
# 'visitors_revenue_A:'
#       visitorId  sum_revenue  N_transaction
# 58    611059232        29150              3
# 211  2108163459         1850              3
# 310  2988190573        67190              3
# 409  3908431265         4250              3
# 416  3967698036         2979              3
# ..          ...          ...            ...
# 146  1402025725         5555              1
# 145  1398592185          390              1
# 144  1388079388          420              1
# 143  1378148355         1060              1
# 444  4278982564        24744              1
#
# [445 rows x 3 columns]
# 'visitors_revenue_B:'
#       visitorId  sum_revenue  N_transaction
# 347  2742574263        42593              3
# 33    249864742         6800              3
# 486  3935952912         6324              2
# 256  2025197455        12850              2
# 418  3332057097         5570              2
# ..          ...          ...            ...
# 171  1388838483         7300              1
# ...

# %% [markdown]
# **По "сырым" данным получаем следующую оценку статистической значимости наличия различий между группами В и А.**
#
# **При пороге значимости а = 0,05 нулевую гипотезу о том, что статистически значимые различия в среднем чеке заказов между группами А и В отсутствуют, оснований отклонять нет. Выбираем нулевую гипотезу: различия в среднем чеке заказов между группами B и А отсутствуют. При этом относительный прирост среднего чека заказов группы B равен примерно 27%, что может объясняться наличием аномальных значений.**
#
# **Критерий Манна-Уитни применяли сначала к последовательностям выручек "visitors_revenue_A[sum_revenue]", а затем к более точным последовательностям средних чеков "visitors_revenue_A[sum_revenue]/visitors_revenue_А['N_transaction']". Если бы все покупатели имели только по одному заказу, то последовательности были бы идентичны. И чем больше покупателей с кол-вом заказов >1, тем сильнее различаются эти последовательности. При использовании более точной последовательности средних чеков критерий Манна-Уитни дает более высокую статистическую значимость (82% против 72,5%) отсутствия различий в среднем чеке между группами А и В.**

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# А вот тут уже не совсем верно: в случае среднего чека в тест нужно подавать не аналог предыдущего пункта, но для стоимости заказов, а всего лишь два числа - средний чек по группам А и В, по аналогии с тренажёром.
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Ошибка исправлена. Изменения внесены в код и выводы/комментарии.
#
#   Замечание реализовано.
#
#     Алексей, в теории, которая в тренажере, хорошо рассматривается случай со средним кол-вом заказов, а средний чек совсем мельком, в 2-х строчках. При этом полностью опущен вопрос, - почему такое различие в подготовке данных при применении критерия? И если была бы иная, какая-то третья метрика, потребовался еще какой-либо иной метод подготовки данных для применения критерия? Чем определяется метод подготовки данных? Ты можешь как-либо прокомментировать эти вопросы или дать ссылку, где эти вопросы рассмотрены?
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.
#
# Как по мне, в случае среднего чека было бы корректно применить такой же подход, как и для среднего количества заказов - сделать массив из стоимости покупок и добавить нули тем, кто их не совершил. Почему автор выбрал подход, когда для среднего чека мы всего лишь подаём два числа в тест - для меня загадка, в целом это выглядит довольно странно. Я рад, что ты задаёшь такие вопросы - уверен, из тебя выйдет (или уже вышел) хороший аналитик:)

# %% [markdown]
# ### ФД. Вычисление статистической значимости различий в среднем количестве заказов на посетителя между группами по «очищенным» данным. Выводы и предположения.

# %%
# выберем пользователей с числом заказов больше (perc1 = 95) и суммой заказа больше (perc2 = 95) долл
perc1 = 95
perc2 = 95
abnormal_visitors = pd.concat(
    [visitors_transactions[visitors_transactions['N_transactions'] > 
                           np.percentile(visitors_transactions['N_transactions'], perc1)]['visitorId'],
     visitors_revenue[visitors_revenue['sum_revenue'] > 
                      np.percentile(visitors_revenue['sum_revenue'], perc2)]['visitorId']
    ], axis=0).drop_duplicates().sort_values()

print(f'Кол-во покупателей с числом заказов больше {np.percentile(visitors_transactions["N_transactions"], 95)} \
и суммой заказа больше {round(np.percentile(visitors_revenue["sum_revenue"], 95))} долл - \
{abnormal_visitors.count()} пользователей или {round(abnormal_visitors.count()/orders["visitorId"].count()*100,1)}%\
 от общего числа пользователей')
# Out:
# Кол-во покупателей с числом заказов больше 1.0 и суммой заказа больше 28910 долл - 79 пользователей или 7.8% от общего числа пользователей

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отфильтровали аномалии, посчитали потери пользователей в абсолютном выражении - отлично!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Значения границ для фильтрации заданы руками - такой подход делает твоё решение зависимым от внешних данных: при их изменении тебе придётся вносить изменения в код, чтобы текущее решение адекватно работало для других А/В тестов. Очень удобно использовать в качестве значения результат метода для расчёта персентилей.
#
# Например вместо `orders > 2` лучше будет сделать `orders > np.percentile(x, 95)` - такой подход сделает решение более универсальным.
#
# </div>
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Согласен. И параметр "95" желательно сделать внешним. Изменения внесены.
#
# Замечание реализовано.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Помимо абсолютных потерь пользователей после фильтрации очень важно также оценить потери и в относительном выражении: любой вид потерь из этих двух сам по себе недостаточно информативен, а вот вместе они уже помогут читателю составить полную картину о масштабе потерь.
#
# </div>
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Изменения внесены. Добавлен подсчет доли покупателей с аномальными значениями кол-ва и сумм заказов в %.
#
#   Замечание реализовано.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# формируем выборку без пользователей с аномальными значениями по группе А к проверке критерием Манна-Уитни
sample_A_filtered = pd.concat(
    [
     visitors_transactions_A.query('visitorId not in @abnormal_visitors')
        ['N_transactions'],
     pd.Series(0,index=np.arange(N_zero_A), name='transactions')
    ], axis=0)



# формируем выборку по группе В к проверке критерием Манна-Уитни  np.logical_not(visitors_transactions_A['visitorId'].isin(abnormal_visitors))
sample_B_filtered = pd.concat(
    [
     visitors_transactions_B[np.logical_not(visitors_transactions_B['visitorId'].isin(abnormal_visitors))]
        ['N_transactions'],
     pd.Series(0,index=np.arange(N_zero_B), name='transactions')
    ], axis=0)

display(sample_A, sample_B)

print('p-value = ', round(st.mannwhitneyu(sample_A_filtered, sample_B_filtered)[1], 5))
print('Относительный прирост среднего числа заказов группы B =','{0:.2%}'
      .format(sample_B_filtered.mean()/sample_A_filtered.mean()- 1))
# Out:
# 0.0        1
# 1.0        1
# 2.0        1
# 3.0        1
# 4.0        1
#           ..
# 18197.0    0
# 18198.0    0
# 18199.0    0
# 18200.0    0
# 18201.0    0
# Length: 18647, dtype: int64
# 0.0        1
# 1.0        1
# 2.0        1
# 3.0        1
# 4.0        1
#           ..
# 18291.0    0
# 18292.0    0
# 18293.0    0
# 18294.0    0
# 18295.0    0
# Length: 18824, dtype: int64
# p-value =  0.01238
# Относительный прирост среднего числа заказов группы B = 18.03%

# %% [markdown]
# **По "фильтрованным" данным значение p-value увеличилось до 0,01244 (было 0.01096), но, по-прежнему, подтверждает статистическую значимость наличия различий между группами В и А. При этом относительный прирост среднего числа заказов группы B по "фильтрованным" данным вырос до 18% (по "сырым" был 16%).**
#
# **Таким образом, при пороге значимости а = 0,05 нулевую гипотезу о том, что статистически значимых различий в среднем числе заказов между группами А и В нет, - отвергаем как по "сырым" данным, так и по "фильтрованным".
# Выбираем альтернативную гипотезу: различия в среднем числе заказов между группами B и А есть.
# При этом относительный прирост среднего числа заказов группы B равен примерно 18%.**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Оценили значимость различий среднего количества заказов на посетителя между группами на очищеных данных - отлично!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Аналогичную проверку на очищенных данных нужно сделать и для среднего чека (с учётом замечания по сырым данным).
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Ошибка исправлена. Изменения в код и выводы/комментарии внесены.
#
#   Замечание реализовано.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ### ФД. Построение графика кумулятивного среднего количества заказов на посетителя по группам по "фильтрованным" данным. Выводы и предположения.

# %%
orders.info()
print(len(orders['visitorId'].unique()), len(orders['transactionId'].unique()))
print(len(abnormal_visitors))

orders_filtered = orders.query('visitorId not in @abnormal_visitors')
orders_filtered.info()
# строим массив уникальных пар значений дат и групп
dates_groups_filtered = orders[['date', 'group']].drop_duplicates().sort_values(by=['date', 'group'])

# агрегируем таблицу "orders_filtered"
orders_filtered_agregg = dates_groups_filtered.apply(
    lambda x:orders_filtered[
        np.logical_and(orders_filtered['date'] <= x['date'], orders_filtered['group'] == x['group'])
                    ]
        .agg({'date':'max', 'group':'max', 'visitorId':'nunique', 'transactionId':'nunique', 'revenue':'sum'}), axis=1
                                    )\
        .sort_values(by=['date', 'group'])
# присваиваем столбцам более понятные названия в таблице "orders_filtered_agregg"
orders_filtered_agregg.columns = ['date', 'group', 'cum_N_buyers', 'cum_N_orders', 'cum_revenue']  

display('Отфильтрованная агрегированная таблица orders_filtered_agregg:', orders_filtered_agregg.head())
orders_filtered_agregg.info()

# агрегируем таблицу "visitors"
visitors_agregg = dates_groups.apply(
    lambda x:visitors[
        np.logical_and(visitors['date'] <= x['date'], visitors['group'] == x['group'])
                    ]
        .agg({'date':'max', 'group':'max', 'visitors':'sum'}), axis=1
                                    )\
        .sort_values(by=['date', 'group'])
# присваиваем столбцам более понятные названия в таблице "visitors_agregg"
visitors_agregg.columns = ['date', 'group', 'cum_N_visitors']  

# посмотрим, что получилось
display(visitors_agregg.head())
visitors_agregg.info()

# создадим единую таблицу "orders_filtered_agregg" на основе "orders_filtered_agregg" и "visitors_agregg"
orders_filtered_visitors_agregg = orders_filtered_agregg.merge(visitors_agregg, left_on=['date', 'group'], \
                                                               right_on=['date', 'group'], how='left')

# посмотрим, что получилось
display(orders_filtered_visitors_agregg.head())
orders_filtered_visitors_agregg.info()

# датафрейм с кумулятивными данными по дням в группе А
orders_filtered_visitors_agregg_A = orders_filtered_visitors_agregg[orders_filtered_visitors_agregg['group'] == 'A']
# датафрейм с кумулятивными данными по дням в группе А
orders_filtered_visitors_agregg_B = orders_filtered_visitors_agregg[orders_filtered_visitors_agregg['group'] == 'B']

plt.figure(figsize=(14,7))
plt.grid()
# строим график кумулятивного среднего количества заказов на посетителя группы А
plt.plot(orders_filtered_visitors_agregg_A['date'], orders_filtered_visitors_agregg_A['cum_N_orders']/orders_filtered_visitors_agregg_A['cum_N_visitors'],\
         label='A')
# строим график кумулятивного среднего количества заказов на посетителя группы В
plt.plot(orders_filtered_visitors_agregg_B['date'], orders_filtered_visitors_agregg_B['cum_N_orders']/orders_filtered_visitors_agregg_B['cum_N_visitors'],\
         label='B')
plt.legend()
plt.title('Фильтр.Д. Графики кумулят-го среднего количества заказов на посетителя по группам', fontsize=18, color='blue')
plt.ylabel('Фильтр.Д. Кумулят-ое среднее кол-во заказов на посетителя', fontsize=15, color='blue')
plt.xticks(rotation=45, ha='right')
plt.axhline(y=0.026, color='red', linestyle='dotted')
plt.axhline(y=0.022, color='green', linestyle='dotted')
plt.xlabel('Даты', fontsize=15, color='blue')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1016 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1016 non-null   int64
#  1   visitorId      1016 non-null   int64
#  2   date           1016 non-null   datetime64[ns]
#  3   revenue        1016 non-null   int64
#  4   group          1016 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 47.6+ KB
# 973 1016
# 79
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 894 entries, 0 to 1194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  894 non-null    int64
#  1   visitorId      894 non-null    int64
#  2   date           894 non-null    datetime64[ns]
#  3   revenue        894 non-null    int64
#  4   group          894 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(1)
# ...

# %% [markdown]
# **График в общем не изменился. Просели несколько (9-10%%) уровни устанавливающихся значений. Различие между группами сохранилось.**

# %% [markdown]
# ### ФД. Построение графика относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A по "фильтрованным" данным.  Выводы и предположения.

# %%
# создадим единую таблицу "orders_filtered_visitors_agregg_АВ" на основе "orders_filtered_visitors_agregg_А" и "orders_filtered_visitors_agregg_B"
orders_filtered_visitors_agregg_AB = orders_filtered_visitors_agregg_A.merge(orders_filtered_visitors_agregg_B, left_on='date', right_on='date', \
                                                           how='left', suffixes=['A','B'])

plt.figure(figsize=(14,7))
plt.grid()
# строим график относительного изменения кумулятивного количества заказов на посетителя группы B к группе A
plt.plot(orders_filtered_visitors_agregg_AB['date'], \
         (orders_filtered_visitors_agregg_AB['cum_N_ordersB']/orders_filtered_visitors_agregg_AB['cum_N_visitorsB'])\
         /(orders_filtered_visitors_agregg_AB['cum_N_ordersA']/orders_filtered_visitors_agregg_AB['cum_N_visitorsA']) - 1,\
         label='(B/A - 1)')
plt.legend()
plt.title('Фильтр.Д. График относит-го изменения кумулят-го кол-ва заказов на посетителя гр.B к гр.A', \
          fontsize=18, color='blue')
#plt.ylabel('Выручка, $', fontsize=15, color='blue')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Даты', fontsize=15, color='blue')
plt.axhline(y=0.18, color='green', linestyle='--')
plt.axhline(y=0, color='black', linestyle='-')
plt.show()

# %% [markdown]
# **Аналогично. График в общем не изменился, но стал более "колебательным".  Различие между группами сохранилось.**

# %% [markdown]
# ### ФД. Вычисление статистической значимости различий в среднем чеке заказа между группами по «очищенным» данным. Выводы и предположения.

# %%
# создадим таблицу с суммой заказов по каждому пользователю в группе А
visitors_revenue_A_filtered = orders.query('group == "A" & visitorId not in @abnormal_visitors')\
.groupby('visitorId', as_index=False)[['revenue', 'transactionId']]\
.agg({'revenue':'sum', 'transactionId':'count'})
visitors_revenue_A_filtered.columns = ['visitorId', 'sum_revenue', 'N_transaction']

# создадим таблицу с кол-вом заказов по каждому пользователю в группе B
visitors_revenue_B_filtered = orders.query('group == "B" & visitorId not in @abnormal_visitors')\
.groupby('visitorId', as_index=False)[['revenue', 'transactionId']]\
.agg({'revenue':'sum', 'transactionId':'count'})
visitors_revenue_B_filtered.columns = ['visitorId', 'sum_revenue', 'N_transaction']

display('visitors_revenue_A_filtered:', visitors_revenue_A_filtered.sort_values(by='N_transaction', ascending=False),'visitors_revenue_B_filtered:', visitors_revenue_B_filtered.sort_values(by='N_transaction', ascending=False))

print('p-value = ', round(st.mannwhitneyu(visitors_revenue_B_filtered['sum_revenue'],\
                                          visitors_revenue_A_filtered['sum_revenue'])[1], 5))
print('p-value = ', round(st.mannwhitneyu(visitors_revenue_B_filtered['sum_revenue']/\
                                          visitors_revenue_B_filtered['N_transaction'],\
                                           visitors_revenue_A_filtered['sum_revenue']/\
                                          visitors_revenue_A_filtered['N_transaction'])[1], 5))
print('Относительный прирост среднего чека заказов группы B =','{0:.2%}'\
      .format(visitors_revenue_B_filtered['sum_revenue'].mean()/visitors_revenue_A_filtered['sum_revenue'].mean()- 1))
# Out:
# 'visitors_revenue_A_filtered:'
#       visitorId  sum_revenue  N_transaction
# 0      11685486         6201              1
# 268  2803209166         1250              1
# 278  2971471657          380              1
# 277  2951649436         2978              1
# 276  2924874435          990              1
# ..          ...          ...            ...
# 133  1414758703         6677              1
# 132  1402025725         5555              1
# 131  1398592185          390              1
# 130  1388079388          420              1
# 407  4278982564        24744              1
#
# [408 rows x 3 columns]
# 'visitors_revenue_B_filtered:'
#       visitorId  sum_revenue  N_transaction
# 0       5114589          570              1
# 304  2572275626         5350              1
# 332  2849720983         2355              1
# 331  2846507753         1120              1
# 330  2830871062          100              1
# ..          ...          ...            ...
# ...

# %% [markdown]
# **По "фильтрованным" данным значение p-value увеличилось до 0,83632 (было 0,82146), что, ещё более подтверждает статистическую значимость отсутствия различий между группами В и А. При этом относительный прирост среднего чека группы B по "фильтрованным" данным упал практически до 0% (-0,9%)(по "сырым" данным был 27%), что можно объяснить исключением аномального заказа, который как раз приходился на группу В, с суммой более чем в 40 раз превышающей пороговое значение 95 перцентиля.**
#
# **Отметим, что после фильтрации у всех покупателей по 1 заказу и, соответственно, выборка по выручке тождественна выборке по среднему чеку, что и видим в значениях p-value, которые тождественно равны.**
#
# **Таким образом, при пороге значимости а = 0,05 нулевую гипотезу о том, что статистически значимых различий в среднем чеке  между группами А и В нет, - принимаем как по "сырым" данным, так и по "фильтрованным".
# Выбираем нулевую гипотезу: различия в среднем чеке заказов между группами B и А нет.
# При этом относительный прирост среднего чека группы B равен примерно -1%.**

# %% [markdown]
# ### ФД. Построение графика кумулятивной выручки по "фильтрованным" по группам. Выводы и предположения.

# %%
orders.info()
print(len(orders['visitorId'].unique()), len(orders['transactionId'].unique()))
print(len(abnormal_visitors))

orders_filtered = orders.query('visitorId not in @abnormal_visitors')
orders_filtered.info()
# строим массив уникальных пар значений дат и групп
dates_groups_filtered = orders[['date', 'group']].drop_duplicates().sort_values(by=['date', 'group'])

# агрегируем таблицу "orders_filtered"
orders_filtered_agregg = dates_groups_filtered.apply(
    lambda x:orders_filtered[
        np.logical_and(orders_filtered['date'] <= x['date'], orders_filtered['group'] == x['group'])
                    ]
        .agg({'date':'max', 'group':'max', 'visitorId':'nunique', 'transactionId':'nunique', 'revenue':'sum'}), axis=1
                                    )\
        .sort_values(by=['date', 'group'])
# присваиваем столбцам более понятные названия в таблице "orders_filtered_agregg"
orders_filtered_agregg.columns = ['date', 'group', 'cum_N_buyers', 'cum_N_orders', 'cum_revenue']  

display('Отфильтрованная агрегированная таблица orders_filtered_agregg:', orders_filtered_agregg.head())
orders_filtered_agregg.info()

# датафрейм с кумулятивными данными по дням в группе А
orders_filtered_agregg_A = orders_filtered_agregg[orders_filtered_agregg['group'] == 'A']
# датафрейм с кумулятивными данными по дням в группе А
orders_filtered_agregg_B = orders_filtered_agregg[orders_filtered_agregg['group'] == 'B']

print('Кол-во элементов orders_filtered_agregg_A:', orders_agregg_A['group'].count())
print('Кол-во элементов orders_filtered_agregg_B:', orders_agregg_B['group'].count())

plt.figure(figsize=(14,7))
plt.grid()
# строим график кумулятивной выручки группы А
plt.plot(orders_filtered_agregg_A['date'], orders_filtered_agregg_A['cum_revenue'], label='A')
# строим график кумулятивной выручки группы В
plt.plot(orders_filtered_agregg_B['date'], orders_filtered_agregg_B['cum_revenue'], label='B')
# создадим единую таблицу "orders_agregg_АВ" на основе "orders_agregg_А" и "orders_agregg_B"
orders_filtered_agregg_AB = orders_filtered_agregg_A.merge(orders_filtered_agregg_B, left_on='date', right_on='date', \
                                                           how='left', suffixes=['A','B'])
plt.plot(orders_filtered_agregg_B['date'], orders_filtered_agregg_AB['cum_revenueB']\
         - orders_filtered_agregg_AB['cum_revenueA'], label='B-А')
plt.legend()
plt.title('Фильтр.Д. Графики кумулятивной выручки по группам', fontsize=18, color='blue')
plt.ylabel('Выручка, $*100000', fontsize=15, color='blue')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Даты', fontsize=15, color='blue')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1016 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1016 non-null   int64
#  1   visitorId      1016 non-null   int64
#  2   date           1016 non-null   datetime64[ns]
#  3   revenue        1016 non-null   int64
#  4   group          1016 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 47.6+ KB
# 973 1016
# 79
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 894 entries, 0 to 1194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  894 non-null    int64
#  1   visitorId      894 non-null    int64
#  2   date           894 non-null    datetime64[ns]
#  3   revenue        894 non-null    int64
#  4   group          894 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(1)
# ...

# %% [markdown]
# **Ступенька на графике группы В устранена, аномальное значение заказа от 2019-08-19 удалено. И теперь четко видно, графики монотонно возрастают, при этом график выручки группы В возрастает все-таки немного быстрее. График разности выручек групп В и А колеблется, но имеет четкий возрастающий тренд. Выручка группы В превышает выручку группы А прогрессивно.**

# %% [markdown]
# ### ФД. Построение графика кумулятивного среднего чека по "фильтрованным" данным по группам.  Выводы и предположения.

# %%
plt.figure(figsize=(14,7))
plt.grid()
# строим график кумулятивного среднего чека группы А
plt.plot(orders_filtered_agregg_A['date'], orders_filtered_agregg_A['cum_revenue']/orders_filtered_agregg_A['cum_N_orders'], label='A')
# строим график кумулятивного среднего чека группы В
plt.plot(orders_filtered_agregg_B['date'], orders_filtered_agregg_B['cum_revenue']/orders_filtered_agregg_B['cum_N_orders'], label='B')
plt.legend()
plt.title('Фильтр.Д. Графики кумулят-го среднего чека по группам', fontsize=18, color='blue')
plt.ylabel('Выручка, $', fontsize=15, color='blue')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Даты', fontsize=15, color='blue')
plt.show()

# %% [markdown]
# **Ступенька на графике группы В устранена, аномальное значение заказа от 2019-08-19 удалено. И теперь четко видно, что графики колеблются, каждый по-своему, имеют затухающий возрастающий тренд и тенденцию к сближению друг с другом. Никакого значимого различия в величине кумулятивного среднего чека по группам нет.**

# %% [markdown]
# ### ФД. Построение графика относительного изменения кумулятивного среднего чека группы B к группе A по "фильтрованным" данным.  Выводы и предположения.

# %%
# создадим единую таблицу "orders_agregg_АВ" на основе "orders_agregg_А" и "orders_agregg_B"
orders_filtered_agregg_AB = orders_filtered_agregg_A.merge(orders_filtered_agregg_B, left_on='date', right_on='date', \
                                                           how='left', suffixes=['A','B'])

plt.figure(figsize=(14,7))
plt.grid()
# строим график относительного изменения кумулятивного среднего чека группы B к группе A
plt.plot(orders_filtered_agregg_AB['date'], (orders_filtered_agregg_AB['cum_revenueB']/orders_filtered_agregg_AB['cum_N_ordersB'])\
         /(orders_filtered_agregg_AB['cum_revenueA']/orders_filtered_agregg_AB['cum_N_ordersA']) - 1, label='(B/A - 1)')
plt.legend()
plt.title('Фильтр.Д. График относит-го измен-я кумулят-го среднего чека гр.B к гр.A', fontsize=18, color='blue')
#plt.ylabel('Выручка, $', fontsize=15, color='blue')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Даты', fontsize=15, color='blue')
plt.axhline(y=0.2, color='green', linestyle='--')
plt.axhline(y=0, color='black', linestyle='-')
plt.show()

# %% [markdown]
# **Аналогично предыдущему графику. Ступенька на графике устранена, аномальное значение заказа от 2019-08-19 удалено. И теперь четко видно, график колеблется, имеют затухающий характер и тенденцию к сближению с нулевой осью, осью абсцисс. Никакого значимого различия в величине кумулятивного среднего чека по группам нет.**

# %% [markdown]
# ### Принятие решения по результатам теста и объяснение его.

# %% [markdown]
# **Подведем итоги,**
#
# **с одной стороны,**
# - есть статистически значимое различие по среднему кол-ву заказов на посетителя между группами как по сырым данным, так и после фильтрации аномалий;
# - графики различия среднего кол-ва заказов на посетителя между группами показывает, что результаты группы B лучше результатов группы A на 16% по "сырым" данным и на 18% после фильтрации аномальных значений,  имеют тенденцию к фиксированию около средних значений в каждой группе;
# - графики кумулятивной выручки показывают нарастающее превышение выручки в группе В над выручкой в группе А
# - нет статистически значимого различия по среднему чеку заказа между группами как по сырым данным, так и после фильтрации аномалий, при этом результаты группы B отличаются от результатов группы A на -0,9% после фильтрации аномальных значений, что можно считать отсутствием различий
# - анализ величины выборки и длительности теста с помощью калькуляторов конверсии подтвердил достаточность представленных данных
#
# **с другой стороны,**
# - графики различия среднего чека между группами не имеют тенденцию к фиксированию около средних значений, имеют еще возрастающий тренд
# - ситуация с размером выборки достаточно пограничная, 13% - минимальный уровень возможного регистрируемого изменения при начальной конверсии в 2,5%.
#
# **На основании представленных результатов делаем вывод:**
# несмотря на отсутствие между группами статистически значимого различия по среднему чеку,
# считаем подтвержденным статистически значимое различие в результатах по кумулятивной конверсии между группами, при этом результаты группы В на 18% лучше результатов группы А, в силу чего при равном среднем чеке между группами подтвержден рост кумулятивной выручки в группе В по сравнению с группой А.
# Соответственно рекомендуем
#
# **признать тест успешным, группу В победившей и тест остановить.**
#
# В случае, если цена ошибки принятия неверного решения много выше стоимости проведения теста, для устранения "пограничности" достаточности размера выборки рекомендуем продлить тест на 31 день, что при данных параметрах набора выборки позволит снизить порог регистрируемого различия до 9% и может привести к фиксированию ситуации в группах со средним чеком.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Решение по тесту принято верное - отличное итоговое резюме.

# %% [markdown]
# ## Итоговый отчет. Выводы и рекомендации.

# %% [markdown]
# Проведен анализ полученных трех датасетов. Файл /datasets/hypothesis.csv. , содержащий данные о гипотезах и параметрах их приоритезации, /datasets/orders.csv.  — информацию о заказах, покупателях, выручке, а /datasets/visitors.csv.  — информацию о посетителях и сессиях.
#
# **Были выполнены следующие работы:**
#
# Изучены исходные файлы
# Проведена предообработка данных
# **Проведена приоритизация гипотез:**
# •	Загрузка данных и получение общей информации о данных.
# •	Применен фреймворк ICE для приоритизации гипотез.
# •	Применен фреймворк RICE для приоритизации гипотез.
# •	Установлена приоритизация гипотез. Даны пояснения.
# **Проведен анализ A/B-теста**
# - Загрузка данных и получение общей информации о данных.
# - Проверка выборок на пересечение целевых групп. Фильтрация пересечений.
# - Построение графика кумулятивной выручки по группам. Выводы и предположения.
# - Построение графика кумулятивного среднего чека по группам. Выводы и предположения.
# - Построение графика относительного изменения кумулятивного среднего чека группы B к группе A. Выводы и предположения.
# - Построение графика кумулятивного среднего количества заказов на посетителя по группам. Выводы и предположения.
# - Построение графика относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A. Выводы и предположения.
# - Построение точечного графика количества заказов по пользователям. Выводы и предположения.
# - Вычисление 95-го и 99-го перцентилей количества заказов на пользователя. Выбор границы для определения аномальных пользователей.
# - Построение точечного графика стоимостей заказов. Выводы и предположения.
# - Вычисление 95-го и 99-го перцентилей стоимости заказов. Выбор границы для определения аномальных заказов.
# - Вычисление статистической значимости различий в среднем количестве заказов на посетителя между группами по «сырым» данным. Выводы и предположения.
# - Вычисление статистической значимости различий в среднем чеке заказа между группами по «сырым» данным. Выводы и предположения.
# - Вычисление статистической значимости различий в среднем количестве заказов на посетителя между группами по «очищенным» данным. Выводы и предположения.
# - Построение графиков среднего количества заказов на посетителя между группами по «очищенным» данным. Выводы и предположения.
# - Вычисление статистической значимости различий в среднем чеке заказа между группами по «очищенным» данным. Выводы и предположения.
# - Построение графиков среднего чека заказов между группами по «очищенным» данным. Выводы и предположения.
# **Принято решение по результатам теста и дано объяснение результатов.**
#
# **По результатам проведенной работы:
#  Выполнена приоритезация гипотез**
# 1.  7	Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2.  2	Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3.  0	Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 4.  6	Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 5.  8	Запустить акцию, дающую скидку на товар в день рождения
# 6.  3	Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 7.  1	Запустить собственную службу доставки, что сократит срок доставки заказов
# 8.  5	Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 9.  4	Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
#
#  **Даны объяснения теста и рекомендации - признать тест успешным, группу В победившей и тест остановить.**
#
#  В случае, если цена ошибки принятия неверного решения много выше стоимости проведения теста, для устранения "пограничности" достаточности размера выборки рекомендовано продлить тест на 31 день.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хороший итоговый вывод!

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Игорь, проект получился на довольно хорошем уровне - ты хорошо постарался, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Работа с кумулятивными данными выполнена отлично - данные собраны корректно, графики построены верно с соблюдением основных правил визуализации, выводы сделаны верные.
#
# В блоке работы с А/В тестом ты верно выбрал инструменты, не забыл сформулировать гипотезы - отличная работа!
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Проверил. Вроде бы ничего не пропустил. Все замечания реализовал. Все отмеченные ошибки исправил. С подтверждением статистической значимости отсутствия различий по среднему чеку мир сразу стал гармоничнее.
#
# Алексей, большое спасибо за ревью и замечания!
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту v.2.
#
# Игорь, все замечания учтены - проект принят!
#
# Спасибо за качественную работу над проектом, желаю успехов в дальнейшем обучении:)
